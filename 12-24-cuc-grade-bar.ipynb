# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# 设置字体，解决中文乱码问题
from pylab import mpl
#mpl.rcParams['font.sans-serif'] = ['SimHei']
mpl.rcParams['font.sans-serif'] = ['Microsoft YaHei']  # 指定默认字体：解决plot不能显示中文问题
mpl.rcParams['axes.unicode_minus'] = False # 解决保存图像是负号'-'显示为方块的问题

import sys, matplotlib
# 生成运行环境信息
print('Python version ' + sys.version)
print('Pandas version ' + pd.__version__)
print('Matplotlib version ' + matplotlib.__version__)
# Out:
# Python version 3.6.0 |Anaconda 4.3.1 (x86_64)| (default, Dec 23 2016, 13:19:00)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
# Pandas version 0.19.2
# Matplotlib version 2.0.0

# %%
df = pd.read_excel("2017CUCGrade.xlsx")
df
# Out:
#    高考省份    招生类别 报考科类  最高分  最低分  平均分  一本线 详细信息
# 0    安徽      一批   文史  614  608  610  515  NaN
# 1    安徽    国家专项   文史  597  587  592  515  NaN
# 2    安徽  提前批小语种   文史  618  604  607  515  NaN
# 3    北京      一批   文史  647  624  629  555  NaN
# 4    北京  提前批小语种   文史  623  615  618  555  NaN
# 5    北京  中外合作办学   文史  626  616  619  555  NaN
# 6    福建      一批   文史  588  573  578  489  NaN
# 7    福建  提前批小语种   文史  574  566  570  489  NaN
# 8    甘肃      一批   文史  591  577  583  505  NaN
# 9    甘肃    国家专项   文史  569  558  565  505  NaN
# 10   广东      一批   文史  611  591  597  520  NaN
# 11   广东  提前批小语种   文史  590  586  588  520  NaN
# 12   广东  中外合作办学   文史  583  568  573  520  NaN
# 13   广西      一批   文史  628  591  608  535  NaN
# 14   广西    国家专项   文史  573  549  566  535  NaN
# 15   广西  提前批小语种   文史  611  592  603  535  NaN
# 16   贵州      一批   文史  647  626  639  545  NaN
# 17   贵州    国家专项   文史  638  615  627  545  NaN
# 18   贵州  中外合作办学   文史  622  608  615  545  NaN
# 19   海南      一批   文史  823  783  799  656  NaN
# 20   海南  提前批小语种   文史  788  783  786  656  NaN
# 21   河北    国家专项   文史  608  602  606  517  NaN
# 22   河北  提前批小语种   文史  621  615  617  517  NaN
# 23   河北      一批   文史  639  626  631  517  NaN
# 24   河南      一批   文史  612  596  608  516  NaN
# 25   河南    国家专项   文史  601  584  595  516  NaN
# 26  黑龙江      一批   文史  602  587  592  481  NaN
# 27  黑龙江  提前批小语种   文史  587  579  584  481  NaN
# 28  黑龙江  中外合作办学   文史  547  540  543  481  NaN
# 29   湖北      一批   文史  614  595  607  528  NaN
# ..  ...     ...  ...  ...  ...  ...  ...  ...
# 39   江西      一批   文史  606  603  604  533  NaN
# 40   江西    国家专项   文史  598  594  595  533  NaN
# 41   江西  提前批小语种   文史  597  591  594  533  NaN
# 42   辽宁      一批   文史  613  604  607  532  NaN
# 43   辽宁  提前批小语种   文史  600  600  600  532  NaN
# 44   辽宁  中外合作办学   文史  603  597  600  532  NaN
# 45  内蒙古      一批   文史  603  547  577  472  NaN
# 46   宁夏      一批   文史  603  587  596  519  NaN
# 47   青海      一批   文史  567  513  538  463  NaN
# 48   青海    国家专项   文史  519  519  519  463  NaN
# 49   山东      一批   文史  618  612  614  529  NaN
# 50   山东  提前批小语种   文史  614  599  608  529  NaN
# 51   山东  中外合作办学   文史  602  584  590  529  NaN
# 52   山西      一批   文史  591  579  582  518  NaN
# 53   山西  提前批小语种   文史  576  563  569  518  NaN
# 54   山西  中外合作办学   文史  568  545  553  518  NaN
# 55   陕西      一批   文史  636  620  626  509  NaN
# 56   陕西    国家专项   文史  603  603  603  509  NaN
# 57   四川      一批   文史  623  610  614  537  NaN
# 58   四川    国家专项   文史  595  592  594  537  NaN
# 59   四川  提前批小语种   文史  610  601  604  537  NaN
# 60   四川  中外合作办学   文史  599  584  590  537  NaN
# 61   天津      一批   文史  635  599  608  531  NaN
# 62   天津  提前批小语种   文史  603  590  595  531  NaN
# 63   新疆      一批   文史  607  588  595  486  NaN
# 64   新疆    国家专项   文史  558  553  556  486  NaN
# 65   云南      一批   文史  650  634  638  555  NaN
# 66   云南    国家专项   文史  629  622  626  555  NaN
# 67   重庆      一批   文史  617  609  613  525  NaN
# 68   重庆    国家专项   文史  604  594  599  525    无
#
# [69 rows x 8 columns]

# %%
#df.index
df.columns
#df.values
#type(df.ix[20])
df2 = df.reindex(columns=df.columns.insert(0, '分数差'))
#df.columns
df2
# Out:
#     分数差 高考省份    招生类别 报考科类  最高分  最低分  平均分  一本线 详细信息
# 0   NaN   安徽      一批   文史  614  608  610  515  NaN
# 1   NaN   安徽    国家专项   文史  597  587  592  515  NaN
# 2   NaN   安徽  提前批小语种   文史  618  604  607  515  NaN
# 3   NaN   北京      一批   文史  647  624  629  555  NaN
# 4   NaN   北京  提前批小语种   文史  623  615  618  555  NaN
# 5   NaN   北京  中外合作办学   文史  626  616  619  555  NaN
# 6   NaN   福建      一批   文史  588  573  578  489  NaN
# 7   NaN   福建  提前批小语种   文史  574  566  570  489  NaN
# 8   NaN   甘肃      一批   文史  591  577  583  505  NaN
# 9   NaN   甘肃    国家专项   文史  569  558  565  505  NaN
# 10  NaN   广东      一批   文史  611  591  597  520  NaN
# 11  NaN   广东  提前批小语种   文史  590  586  588  520  NaN
# 12  NaN   广东  中外合作办学   文史  583  568  573  520  NaN
# 13  NaN   广西      一批   文史  628  591  608  535  NaN
# 14  NaN   广西    国家专项   文史  573  549  566  535  NaN
# 15  NaN   广西  提前批小语种   文史  611  592  603  535  NaN
# 16  NaN   贵州      一批   文史  647  626  639  545  NaN
# 17  NaN   贵州    国家专项   文史  638  615  627  545  NaN
# 18  NaN   贵州  中外合作办学   文史  622  608  615  545  NaN
# 19  NaN   海南      一批   文史  823  783  799  656  NaN
# 20  NaN   海南  提前批小语种   文史  788  783  786  656  NaN
# 21  NaN   河北    国家专项   文史  608  602  606  517  NaN
# 22  NaN   河北  提前批小语种   文史  621  615  617  517  NaN
# 23  NaN   河北      一批   文史  639  626  631  517  NaN
# 24  NaN   河南      一批   文史  612  596  608  516  NaN
# 25  NaN   河南    国家专项   文史  601  584  595  516  NaN
# 26  NaN  黑龙江      一批   文史  602  587  592  481  NaN
# 27  NaN  黑龙江  提前批小语种   文史  587  579  584  481  NaN
# 28  NaN  黑龙江  中外合作办学   文史  547  540  543  481  NaN
# 29  NaN   湖北      一批   文史  614  595  607  528  NaN
# ..  ...  ...     ...  ...  ...  ...  ...  ...  ...
# 39  NaN   江西      一批   文史  606  603  604  533  NaN
# 40  NaN   江西    国家专项   文史  598  594  595  533  NaN
# 41  NaN   江西  提前批小语种   文史  597  591  594  533  NaN
# 42  NaN   辽宁      一批   文史  613  604  607  532  NaN
# 43  NaN   辽宁  提前批小语种   文史  600  600  600  532  NaN
# 44  NaN   辽宁  中外合作办学   文史  603  597  600  532  NaN
# 45  NaN  内蒙古      一批   文史  603  547  577  472  NaN
# 46  NaN   宁夏      一批   文史  603  587  596  519  NaN
# 47  NaN   青海      一批   文史  567  513  538  463  NaN
# 48  NaN   青海    国家专项   文史  519  519  519  463  NaN
# 49  NaN   山东      一批   文史  618  612  614  529  NaN
# 50  NaN   山东  提前批小语种   文史  614  599  608  529  NaN
# 51  NaN   山东  中外合作办学   文史  602  584  590  529  NaN
# 52  NaN   山西      一批   文史  591  579  582  518  NaN
# 53  NaN   山西  提前批小语种   文史  576  563  569  518  NaN
# 54  NaN   山西  中外合作办学   文史  568  545  553  518  NaN
# 55  NaN   陕西      一批   文史  636  620  626  509  NaN
# 56  NaN   陕西    国家专项   文史  603  603  603  509  NaN
# 57  NaN   四川      一批   文史  623  610  614  537  NaN
# 58  NaN   四川    国家专项   文史  595  592  594  537  NaN
# 59  NaN   四川  提前批小语种   文史  610  601  604  537  NaN
# 60  NaN   四川  中外合作办学   文史  599  584  590  537  NaN
# 61  NaN   天津      一批   文史  635  599  608  531  NaN
# 62  NaN   天津  提前批小语种   文史  603  590  595  531  NaN
# 63  NaN   新疆      一批   文史  607  588  595  486  NaN
# 64  NaN   新疆    国家专项   文史  558  553  556  486  NaN
# 65  NaN   云南      一批   文史  650  634  638  555  NaN
# 66  NaN   云南    国家专项   文史  629  622  626  555  NaN
# 67  NaN   重庆      一批   文史  617  609  613  525  NaN
# 68  NaN   重庆    国家专项   文史  604  594  599  525    无
#
# [69 rows x 9 columns]

# %%
#df.最高分 - df.最低分 < 10 
#plt.plot(df.最高分 * 2)
#plt.show()
#df.高考省份

# %%
df2.分数差 = df.最高分 - df.最低分
df2
# Out:
#     分数差 高考省份    招生类别 报考科类  最高分  最低分  平均分  一本线 详细信息
# 0     6   安徽      一批   文史  614  608  610  515  NaN
# 1    10   安徽    国家专项   文史  597  587  592  515  NaN
# 2    14   安徽  提前批小语种   文史  618  604  607  515  NaN
# 3    23   北京      一批   文史  647  624  629  555  NaN
# 4     8   北京  提前批小语种   文史  623  615  618  555  NaN
# 5    10   北京  中外合作办学   文史  626  616  619  555  NaN
# 6    15   福建      一批   文史  588  573  578  489  NaN
# 7     8   福建  提前批小语种   文史  574  566  570  489  NaN
# 8    14   甘肃      一批   文史  591  577  583  505  NaN
# 9    11   甘肃    国家专项   文史  569  558  565  505  NaN
# 10   20   广东      一批   文史  611  591  597  520  NaN
# 11    4   广东  提前批小语种   文史  590  586  588  520  NaN
# 12   15   广东  中外合作办学   文史  583  568  573  520  NaN
# 13   37   广西      一批   文史  628  591  608  535  NaN
# 14   24   广西    国家专项   文史  573  549  566  535  NaN
# 15   19   广西  提前批小语种   文史  611  592  603  535  NaN
# 16   21   贵州      一批   文史  647  626  639  545  NaN
# 17   23   贵州    国家专项   文史  638  615  627  545  NaN
# 18   14   贵州  中外合作办学   文史  622  608  615  545  NaN
# 19   40   海南      一批   文史  823  783  799  656  NaN
# 20    5   海南  提前批小语种   文史  788  783  786  656  NaN
# 21    6   河北    国家专项   文史  608  602  606  517  NaN
# 22    6   河北  提前批小语种   文史  621  615  617  517  NaN
# 23   13   河北      一批   文史  639  626  631  517  NaN
# 24   16   河南      一批   文史  612  596  608  516  NaN
# 25   17   河南    国家专项   文史  601  584  595  516  NaN
# 26   15  黑龙江      一批   文史  602  587  592  481  NaN
# 27    8  黑龙江  提前批小语种   文史  587  579  584  481  NaN
# 28    7  黑龙江  中外合作办学   文史  547  540  543  481  NaN
# 29   19   湖北      一批   文史  614  595  607  528  NaN
# ..  ...  ...     ...  ...  ...  ...  ...  ...  ...
# 39    3   江西      一批   文史  606  603  604  533  NaN
# 40    4   江西    国家专项   文史  598  594  595  533  NaN
# 41    6   江西  提前批小语种   文史  597  591  594  533  NaN
# 42    9   辽宁      一批   文史  613  604  607  532  NaN
# 43    0   辽宁  提前批小语种   文史  600  600  600  532  NaN
# 44    6   辽宁  中外合作办学   文史  603  597  600  532  NaN
# 45   56  内蒙古      一批   文史  603  547  577  472  NaN
# 46   16   宁夏      一批   文史  603  587  596  519  NaN
# 47   54   青海      一批   文史  567  513  538  463  NaN
# 48    0   青海    国家专项   文史  519  519  519  463  NaN
# 49    6   山东      一批   文史  618  612  614  529  NaN
# 50   15   山东  提前批小语种   文史  614  599  608  529  NaN
# 51   18   山东  中外合作办学   文史  602  584  590  529  NaN
# 52   12   山西      一批   文史  591  579  582  518  NaN
# 53   13   山西  提前批小语种   文史  576  563  569  518  NaN
# 54   23   山西  中外合作办学   文史  568  545  553  518  NaN
# 55   16   陕西      一批   文史  636  620  626  509  NaN
# 56    0   陕西    国家专项   文史  603  603  603  509  NaN
# 57   13   四川      一批   文史  623  610  614  537  NaN
# 58    3   四川    国家专项   文史  595  592  594  537  NaN
# 59    9   四川  提前批小语种   文史  610  601  604  537  NaN
# 60   15   四川  中外合作办学   文史  599  584  590  537  NaN
# 61   36   天津      一批   文史  635  599  608  531  NaN
# 62   13   天津  提前批小语种   文史  603  590  595  531  NaN
# 63   19   新疆      一批   文史  607  588  595  486  NaN
# 64    5   新疆    国家专项   文史  558  553  556  486  NaN
# 65   16   云南      一批   文史  650  634  638  555  NaN
# 66    7   云南    国家专项   文史  629  622  626  555  NaN
# 67    8   重庆      一批   文史  617  609  613  525  NaN
# 68   10   重庆    国家专项   文史  604  594  599  525    无
#
# [69 rows x 9 columns]

# %%
df2.sort_values(["招生类别", "分数差"], axis=0, ascending=[False, False])
df3 = df2.sort_values(["最高分"], axis=0, ascending=[False])
#df2.sort_index(axis=0, ascending=False)
df3

df
#dfn = df [["最高分", "最低分"]]
#dfn.ix[3] - dfn.ix[2]
df [df.最高分 > 700]
# Out:
#    高考省份    招生类别 报考科类  最高分  最低分  平均分  一本线 详细信息
# 19   海南      一批   文史  823  783  799  656  NaN
# 20   海南  提前批小语种   文史  788  783  786  656  NaN

# %%
df2.describe()
# Out:
#              分数差         最高分         最低分         平均分         一本线
# count  69.000000   69.000000   69.000000   69.000000   69.000000
# mean   14.130435  603.739130  589.608696  596.144928  520.275362
# std    10.891055   57.224186   55.526416   55.880459   45.267143
# min     0.000000  372.000000  368.000000  370.000000  333.000000
# 25%     6.000000  591.000000  579.000000  584.000000  515.000000
# 50%    13.000000  606.000000  594.000000  600.000000  528.000000
# 75%    18.000000  621.000000  608.000000  613.000000  535.000000
# max    56.000000  823.000000  783.000000  799.000000  656.000000

# %%
df2.boxplot()
### 在这里使用 plt.savefig() 保存图片  
plt.show()

# %%
df3.columns
# Out:
# Index(['分数差', '高考省份', '招生类别', '报考科类', '最高分', '最低分', '平均分', '一本线', '详细信息'], dtype='object')

# %%
# pandas 转换为 echart 数据
# REF: http://pyecharts.org/#/zh-cn/prepare?id=pandasampnumpy-%E7%AE%80%E5%8D%95%E7%A4%BA%E4%BE%8B

[x for x in df3.高考省份][:10]
# Out:
# ['海南', '海南', '云南', '贵州', '北京', '河北', '贵州', '陕西', '天津', '湖南']

# %%
from pyecharts import Bar,Page

page = Page() # 新建 page 布局
df3 = df2.sort_values(["分数差"], axis=0, ascending=[False])

attr = [x for x in df3.高考省份][:20]
v1 = [x for x in df3.最高分][:20]
v2 = [x for x in df3.平均分][:20]
v3= [x for x in df3.最低分][:20]
bar = Bar("柱状图数据堆叠示例")
bar.add("最高分", attr, v1, is_datazoom_show=True, is_datazoom_extra_show=True, mark_point=["max", "min"], mark_line=["average"])
bar.add("平均分", attr, v2, is_datazoom_show=True, is_datazoom_extra_show=True, mark_point=["max", "min"], mark_line=["average"])
bar.add("最低分", attr, v3, is_datazoom_show=True, is_datazoom_extra_show=True, mark_point=["max", "min"], mark_line=["average"])
page.add(bar) # 在 page 中增加 bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="013d999cf6044f709d7859debdf660e4" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_013d999cf6044f709d7859debdf660e4 = echarts.init(document.getElementById('013d999cf6044f709d7859debdf660e4'), 'light', {renderer: 'canvas'});
#
# var option_013d999cf6044f709d7859debdf660e4 = {
#     "title": [
#         {
#             "text": "\u67f1\u72b6\u56fe\u6570\u636e\u5806\u53e0\u793a\u4f8b",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 447729,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u6700\u9ad8\u5206",
#             "data": [
#                 603.0,
#                 567.0,
#                 823.0,
#                 628.0,
#                 635.0,
#                 632.0,
#                 573.0,
#                 638.0,
#                 647.0,
#                 568.0,
#                 610.0,
#                 647.0,
#                 611.0,
#                 614.0,
#                 607.0,
#                 611.0,
#                 602.0,
#                 586.0,
#                 601.0,
#                 603.0
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": [
#                     {
#                         "type": "max",
#                         "name": "Maximum",
#                         "symbol": "pin",
#                         "symbolSize": 50,
#                         "label": {
#                             "normal": {
#                                 "textStyle": {
#                                     "color": "#fff"
#                                 }
#                             }
#                         }
#                     },
#                     {
#                         "type": "min",
#                         "name": "Minimum",
#                         "symbol": "pin",
#                         "symbolSize": 50,
#                         "label": {
#                             "normal": {
#                                 "textStyle": {
#                                     "color": "#fff"
#                                 }
#                             }
#                         }
#                     }
#                 ]
#             },
#             "markLine": {
#                 "data": [
#                     {
#                         "type": "average",
#                         "name": "mean-Value"
#                     }
#                 ],
#                 "symbolSize": 10
#             },
#             "seriesId": 447729
#         },
#         {
#             "type": "bar",
#             "name": "\u5e73\u5747\u5206",
#             "data": [
#                 577.0,
#                 538.0,
#                 799.0,
#                 608.0,
#                 608.0,
#                 625.0,
#                 566.0,
#                 627.0,
#                 629.0,
#                 553.0,
#                 604.0,
#                 639.0,
#                 597.0,
#                 607.0,
#                 595.0,
#                 603.0,
#                 590.0,
#                 579.0,
#                 595.0,
#                 596.0
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": [
#                     {
#                         "type": "max",
#                         "name": "Maximum",
#                         "symbol": "pin",
#                         "symbolSize": 50,
#                         "label": {
#                             "normal": {
#                                 "textStyle": {
#                                     "color": "#fff"
#                                 }
#                             }
#                         }
#                     },
#                     {
#                         "type": "min",
#                         "name": "Minimum",
#                         "symbol": "pin",
#                         "symbolSize": 50,
#                         "label": {
#                             "normal": {
#                                 "textStyle": {
#                                     "color": "#fff"
#                                 }
#                             }
#                         }
#                     }
#                 ]
#             },
#             "markLine": {
#                 "data": [
#                     {
#                         "type": "average",
#                         "name": "mean-Value"
#                     }
#                 ],
#                 "symbolSize": 10
#             },
#             "seriesId": 447729
#         },
#         {
#             "type": "bar",
#             "name": "\u6700\u4f4e\u5206",
#             "data": [
#                 547.0,
#                 513.0,
#                 783.0,
#                 591.0,
#                 599.0,
#                 607.0,
#                 549.0,
#                 615.0,
#                 624.0,
#                 545.0,
#                 587.0,
#                 626.0,
#                 591.0,
#                 595.0,
#                 588.0,
#                 592.0,
#                 584.0,
#                 568.0,
#                 584.0,
#                 587.0
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": [
#                     {
#                         "type": "max",
#                         "name": "Maximum",
#                         "symbol": "pin",
#                         "symbolSize": 50,
#                         "label": {
#                             "normal": {
#                                 "textStyle": {
#                                     "color": "#fff"
#                                 }
#                             }
#                         }
#                     },
#                     {

# %%
from pyecharts import Bar

df3 = df2.sort_values(["分数差"], axis=0, ascending=[False])

attr = [x for x in df3.高考省份][:20]
v1 = [x for x in df3.分数差][:20]
bar2 = Bar("分数差计算统计")
bar2.add("分数差", attr, v1, is_datazoom_show=True, is_datazoom_extra_show=True, mark_point=["max", "min"], mark_line=["average"])
page.add(bar2)  # 在 page 中增加 bar

### 在 这里使用 render() 保持可视化网页
page.render()
bar2
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="6bf2105415c64b24b3505a93937b4d54" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_6bf2105415c64b24b3505a93937b4d54 = echarts.init(document.getElementById('6bf2105415c64b24b3505a93937b4d54'), 'light', {renderer: 'canvas'});
#
# var option_6bf2105415c64b24b3505a93937b4d54 = {
#     "title": [
#         {
#             "text": "\u5206\u6570\u5dee\u8ba1\u7b97\u7edf\u8ba1",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 500313,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5206\u6570\u5dee",
#             "data": [
#                 56.0,
#                 54.0,
#                 40.0,
#                 37.0,
#                 36.0,
#                 25.0,
#                 24.0,
#                 23.0,
#                 23.0,
#                 23.0,
#                 23.0,
#                 21.0,
#                 20.0,
#                 19.0,
#                 19.0,
#                 19.0,
#                 18.0,
#                 18.0,
#                 17.0,
#                 16.0
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": [
#                     {
#                         "type": "max",
#                         "name": "Maximum",
#                         "symbol": "pin",
#                         "symbolSize": 50,
#                         "label": {
#                             "normal": {
#                                 "textStyle": {
#                                     "color": "#fff"
#                                 }
#                             }
#                         }
#                     },
#                     {
#                         "type": "min",
#                         "name": "Minimum",
#                         "symbol": "pin",
#                         "symbolSize": 50,
#                         "label": {
#                             "normal": {
#                                 "textStyle": {
#                                     "color": "#fff"
#                                 }
#                             }
#                         }
#                     }
#                 ]
#             },
#             "markLine": {
#                 "data": [
#                     {
#                         "type": "average",
#                         "name": "mean-Value"
#                     }
#                 ],
#                 "symbolSize": 10
#             },
#             "seriesId": 500313
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5206\u6570\u5dee"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "xAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "data": [
#                 "\u5185\u8499\u53e4",
#                 "\u9752\u6d77",
#                 "\u6d77\u5357",
#                 "\u5e7f\u897f",
#                 "\u5929\u6d25",
#                 "\u6e56\u5357",
#                 "\u5e7f\u897f",
#                 "\u8d35\u5dde",
#                 "\u5317\u4eac",
#                 "\u5c71\u897f",
#                 "\u6e56\u5357",
#                 "\u8d35\u5dde",
#                 "\u5e7f\u4e1c",
#                 "\u6e56\u5317",
#                 "\u65b0\u7586",
#                 "\u5e7f\u897f",
#                 "\u5c71\u4e1c",
#                 "\u6e56\u5317",
#                 "\u6cb3\u5357",
#                 "\u5b81\u590f"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "value",
#             "splitLine": {
#                 "show": true
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             }
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "dataZoom": [
#         {
#             "show": true,
#             "type": "slider",
#             "start": 50,
#             "end": 100,
#             "orient": "horizontal"
#         },
#         {
#             "show": true,
#             "type": "slider",
#             "start": 50,
#             "end": 100,
#             "orient": "vertical"
#         }
#     ]
# };
# myChart_6bf2105415c64b24b3505a93937b4d54.setOption(option_6bf2105415c64b24b3505a93937b4d54);
#
#     });
# </script>

# %%
df3.to_json("test.json")
